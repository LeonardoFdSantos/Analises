# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
import numpy as np
import matplotlib.pyplot as plt

# %%
medidas_dataset = pd.read_excel('medidas.xls')
del medidas_dataset['Unnamed: 7']
del medidas_dataset['Unnamed: 13']
del medidas_dataset['Unnamed: 15']
medidas_dataset.dropna()
medidas_dataset.head() #.T = Transposição de dados.
# Out:
#                   Data Fases Tensão\n(Vac)* Corrente\n(A)* Fat.Pot.  \
# 0                  NaN   NaN            NaN            NaN      NaN
# 1                  NaN   NaN            NaN            NaN      NaN
# 2  2019-07-07 05:05:10    R:         221.25           1.57     0.16
# 3                  NaN    S:         218.48           1.45     0.03
# 4                  NaN    T:          218.7           1.55     0.32
#
#   Pot.Aparente\n(kVA) Pot.Ativa\n(kW)* Pot.Reativa\n(kVAr)* Falta KVAr* KWh**  \
# 0                 NaN              NaN                  NaN         NaN   NaN
# 1                 NaN              NaN                  NaN         NaN   NaN
# 2                0.34             0.05                 0.34           0     0
# 3                0.31                0                 0.31           0     0
# 4                0.33              0.1                 0.32           0     0
#
#   KWh Ponta** KVArh** KVArh Ponta** Exc. KVAr*
# ...
